# %% [markdown]
# <a href="https://colab.research.google.com/github/tjwei/NDHU_AM1130/blob/master/2018_Wee08_pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2*np.pi, 1000)

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, 0.1*x**3-0.2*x**2-x+1)

# %%
plt.plot(np.cos(x), np.sin(x))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(0, 2*np.pi, 6)
plt.plot(np.cos(t+0.1*np.pi), np.sin(t+0.1*np.pi))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(np.pi/2, np.pi/2+2*np.pi, 6)
plt.plot(np.cos(t), np.sin(t))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(np.pi/2, np.pi/2+2*np.pi, 12)
plt.plot(np.cos(t), np.sin(t))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(np.pi/2, np.pi/2+4*np.pi, 6)
plt.plot(np.cos(t), np.sin(t))
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(np.pi/2, np.pi/2+1*2*np.pi, 13)
plt.plot(np.cos(t), np.sin(t))

# %%
plt.xkcd()

# %%
plt.figure(figsize=(5,5))
t=np.linspace(np.pi/2, np.pi/2+2*np.pi, 11)
r = np.array([1, .3] * 5 + [1])
plt.plot(np.cos(t)*r, np.sin(t)*r)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(5,5))
t=np.linspace(0, 4*np.pi, 1000)
r = np.cos(5/2*t)
plt.plot(np.cos(t)*r, np.sin(t)*r)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
x = np.linspace(0, 3, 30)
plt.plot(x, x**2, 'b.', label='x^2')
plt.plot(x, np.sin(x), 'g', label='sin(x)')
plt.plot(x, np.abs(x), 'k', label='|x|')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.xkcd(10, randomness=100)

# %%
plt.style.use('classic')
x = np.linspace(0, 3, 30)
plt.plot(x, x**2, 'b.', label='x^2')
plt.plot(x, np.sin(x), 'g', label='sin(x)')
plt.plot(x, np.abs(x), 'k', label='|x|')
plt.legend()

# %%
plt.style.available
# Out:
# ['seaborn-darkgrid',
#  'fast',
#  'dark_background',
#  'bmh',
#  'seaborn-paper',
#  'grayscale',
#  'seaborn-white',
#  'seaborn',
#  'seaborn-colorblind',
#  'Solarize_Light2',
#  'seaborn-talk',
#  'fivethirtyeight',
#  'seaborn-dark-palette',
#  '_classic_test',
#  'seaborn-pastel',
#  'seaborn-whitegrid',
#  'seaborn-muted',
#  'seaborn-bright',
#  'seaborn-deep',
#  'classic',
#  'seaborn-poster',
#  'seaborn-notebook',
#  'seaborn-ticks',
#  'seaborn-dark',
#  'ggplot']

# %%
plt.style.use('seaborn-dark-palette')
x = np.linspace(0, 3, 30)
plt.plot(x, x**2, 'b.', label='x^2')
plt.plot(x, np.sin(x), 'g', label='sin(x)')
plt.plot(x, np.abs(x), 'k', label='|x|')
plt.legend()

# %%
import seaborn as sns
sns.set(style="ticks")

# Load the example tips dataset
tips = sns.load_dataset("tips")

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[tips.sex=='Male'].tip.mean()
# Out:
# 3.0896178343949043

# %%
tips[tips.sex=='Male'].total_bill.mean(), tips[tips.sex=='Female'].total_bill.mean()
# Out:
# (20.744076433121016, 18.056896551724133)

# %%
tips[tips.time=='Dinner'].total_bill.sum()/tips[tips.time=='Dinner'].size.sum()
# Out:
# 2.9710227272727274

# %%
tips[tips.time=='Lunch'].total_bill.sum()/tips[tips.time=='Lunch'].size.sum()
# Out:
# 2.452668067226891

# %%
plt.plot(tips[tips.time=='Dinner'].total_bill)

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips, palette="PRGn")
sns.despine(offset=10, trim=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 6))

# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=corr_df, palette="Set3", bw=.2, cut=1, linewidth=1)

# Finalize the figure
ax.set(ylim=(-.7, 1.05))
sns.despine(left=True, bottom=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
sns.violinplot(data=tips, x='day', y='total_bill', hue='smoker', palette="PRGn", bw=.2, cut=1, linewidth=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:637: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data[hue_mask])
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:932: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data[hue_mask])

# %%
from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax = plt.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.afmhot, linewidth=0.2)
plt.show()

# %%
# !wget https://raw.githubusercontent.com/tjwei/class2016/master/img/e_crop.png
# Out:
# --2018-10-30 06:19:04--  https://raw.githubusercontent.com/tjwei/class2016/master/img/e_crop.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 714409 (698K) [image/png]
# Saving to: ‘e_crop.png’
#
# e_crop.png          100%[===================>] 697.67K  --.-KB/s    in 0.06s
#
# 2018-10-30 06:19:04 (10.9 MB/s) - ‘e_crop.png’ saved [714409/714409]

# %%
plt.imshow(plt.imread('e_crop.png'))

# %%
Z = plt.imread('e_crop.png')[::10,::10, 0]
Z.shape
# Out:
# (116, 115)

# %%
from mpl_toolkits.mplot3d import Axes3D
Y,X = np.indices(Z.shape)

ax = plt.gca(projection='3d')
surf = ax.plot_surface(X, Y, 1-Z, rstride=1, cstride=3, cmap=plt.cm.afmhot, linewidth=0.1)
plt.show()
